# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("inputdf.csv")
df = df.drop(['Unnamed: 0'], axis =1)
df['user_id'] = np.random.randint(1,5, size=len(df))

# %%
df.head()
# Out:
#                                        Job Title             Salary Estimate  \
# 0                                 Data Scientist  $80K-$120K (Employer est.)
# 1                               Data Scientist 1  $80K-$120K (Employer est.)
# 2                                 Data Scientist  $80K-$120K (Employer est.)
# 3  Certified Lab Scientist or Certified Lab Tech  $80K-$120K (Employer est.)
# 4                          Senior Data Scientist  $80K-$120K (Employer est.)
#
#                                      Job Description  Rating  \
# 0  About ClearCut Analytics\nClearCut was founded...     4.8
# 1  At NGL, we strive to make data-driven decision...     3.0
# 2  Job Description:Metron is seeking talented Dat...     3.0
# 3  Prairie Ridge Health is looking for a team mem...    -1.0
# 4  Sartorius Stedim Data Analytics, a market lead...     3.6
#
#                                     Company Name         Location  \
# ...

# %%
df.describe()
# Out:
#             Rating      Founded   min_salary   max_salary   avg_salary  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      3.562600  1682.456000    71.877000   123.145000    97.511000
# std       1.266019   716.558907    35.059165    46.411701    39.370807
# min      -1.000000    -1.000000    20.000000    28.000000    24.000000
# 25%       3.300000  1948.750000    50.000000    94.000000    75.000000
# 50%       3.800000  1996.000000    69.000000   120.000000    96.000000
# 75%       4.200000  2008.000000    88.250000   147.000000   121.750000
# max       5.000000  2019.000000   149.000000   234.000000   191.500000
#
#             Python            R        Spark          AWS        Excel  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.681000     0.005000     0.257000     0.267000     0.475000
# std       0.466322     0.070569     0.437198     0.442614     0.499624
# ...

# %% [markdown]
# ## Univariate Analysis

# %%
df_cat = df[['job_simp', 'job_state', 'Size','Sector','Revenue','Industry', 'Type of ownership']]

# %%
df_cat1 = df[['Python', 'SQL','R','AWS','Spark',  'Excel']]

# %% [markdown]
# # Categorical Univariate Analysis - 2 Categories

# %%
plt.rcParams['figure.figsize'] = [15, 6]
for i in df_cat1.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    plt.pie(x=cat_num, autopct="%.1f%%",pctdistance=0.5)
    labels = df_cat1.index
    plt.legend(labels, loc="right")
    plt.show()
# Out:
# graph for Python: total = 2
# graph for SQL: total = 2
# graph for R: total = 2
# graph for Spark: total = 2
# graph for AWS: total = 2
# graph for Excel: total = 2

# %% [markdown]
# # Categorical Univariate Analysis - Multiple Categories

# %%
plt.rcParams['figure.figsize'] = [15, 6]
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for job_simp: total = 6
# graph for job_state: total = 41
# graph for Size: total = 8
# graph for Sector: total = 25
# graph for Revenue: total = 14
# graph for Industry: total = 71
# graph for Type of ownership: total = 11

# %% [markdown]
# # Continuous Univariate Analysis

# %%
plt.rcParams['figure.figsize'] = [10, 15]
fig, axes = plt.subplots(nrows=3, ncols=1)
ax0, ax1, ax2 = axes.flatten()


ax0.hist(df['avg_salary'])
ax0.set_title('Average Salary Histogram')

ax1.hist(df['age'])
ax1.set_title('Age Histogram')

ax2.hist(df['Rating'])
ax2.set_title('Rating Histogram')

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %%
plt.rcParams['figure.figsize'] = [12, 8]
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age','avg_salary','Rating','Python','SQL']].corr(),vmax=1, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot = True)
